# %%
from google.colab import drive
ROOT = '/content/drive'
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/drive/MyDrive/Github/web-crawler' 
# replace with your Github username 
GIT_USERNAME = "JackCokebb" 
# definitely replace with your
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "web_crawler" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/MyDrive/Github/web-crawler
# mkdir: cannot create directory ‘/content/drive/MyDrive/Github/web-crawler’: File exists
# GIT_PATH:  https://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@github.com/JackCokebb/web_crawler.git

# %%
# %cd "{PROJECT_PATH}"    
# !git clone "{GIT_PATH}" .
# Out:
# /content/drive/MyDrive/Github/web-crawler
# fatal: destination path '.' already exists and is not an empty directory.

# %%
# !git config --global user.email reo2726@gmail.com
# !git config --global user.name JackCokebb

# %%
#requests -> get site(url) info in the format of HTML
import requests
response =requests.get('https://www.google.com/search?q=lidar&newwindow=1&source=hp&ei=AyfFYfL0LKXk2roP6sigsAs&iflsig=ALs-wAMAAAAAYcU1E38W300LGZi5S0JvCU7vwP4i3xxA&ved=0ahUKEwiygsP0qPv0AhUlslYBHWokCLYQ4dUDCAc&uact=5&oq=lidar&gs_lcp=Cgdnd3Mtd2l6EAMyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEMgUIABCABDIFCAAQgAQyBQgAEIAEOgsILhCABBDHARCjAjoLCC4QgAQQxwEQrwE6BQguEIAEOgsILhCABBDHARDRA1AAWPZ5YLmAAWgEcAB4AIABmgGIAZYKkgEDMC45mAEAoAEBsAEA&sclient=gws-wiz') 
print(response.status_code)
print(response.text)
# Out:
# 200
# <!doctype html><html lang="en"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>lidar - Google Search</title><script nonce="Mr7EZiVlGc8KH94owMobGg==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
# !git add . 
# !git commit -m "update from g-drive"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# Everything up-to-date
